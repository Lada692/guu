# %% [markdown]
# <div class="joplin-table-wrapper"><table><tbody><tr><th><p>Диаграмма C4</p></th><th><p>Что? (Данные)</p></th><th><p>Как? (Функция)</p></th><th><p>Где? (Сеть)</p></th><th><p>Кто? (Люди)</p></th><th><p>Когда? (Время</p></th><th><p>Почему? (Мотивация)</p></th></tr><tr><td><p>Контекстная</p></td><td><p>Метрики бизнеса селлеров:</p><ul><li>Выручка, количество заказов, средний чек, возвраты</li><li>Метрики вовлеченности: DAU/WAU, глубина просмотра, время в приложении, конверсия в целевое действие</li><li>Описания изменений</li></ul></td><td><p>Оценка влияния изменений в приложении на ключевые бизнес-метрики селлеров</p><p>Принятие продуктовых решений о раскатке/откате изменений</p><p>Снижение рисков внедрения негативных изменений</p></td><td><p>Мобильные устройства продавцов (iOS/Android)</p><p>Сервера Ozon</p></td><td><p>Продуктовый аналитик - инициатор и исполнитель исследования</p><p>Продавцы - пользователи приложения, субъекты исследования</p><p>Продукт-менеджер - заказчик оценки</p><p>Команда разработки - реализует изменения</p></td><td><p>До и После внедрения изменения</p></td><td><p>Сложность проведения A/B тестов из-за:</p><p>Дороговизны поддержки нескольких версий продукта</p><p>Уменьшения аудитории, взаимодействующей с обновленной версией продукта</p></td></tr><tr><td><p>Контейнерная</p></td><td><p>Сырые событийные данные (клики, просмотры, показы)</p><p>Агрегированные данные по селлерам</p><p>Мета-информация о селлерах (категория товаров, стаж, регион)</p></td><td><p>Difference-in-Difference - проверка гипотез при помощи сравнения значений метрики в разные периоды времени</p><p>Regression discontinuity design - определение причинно-следственных эффектов вмешательств путем назначения порога, выше или ниже которого назначается вмешательство</p></td><td><p>Хранилище данных DWH: источник сырых и агрегированных данных.</p><p>Среда анализа - Python и JupyterHub</p><p>Система визуализации</p></td><td><p>Продуктовый аналитик</p><p>Data Engineer</p></td><td><p>Период сбора данных</p><p>Момент проведения анализа</p></td><td><p>Целостность методологии: Изолирование эффекта от изменения, минимизируя влияние смешивающих факторов.</p><p>Воспроизводимость: Создание стандартизированного пайплайна анализа для повторного использования.</p><p>Достоверность: Стремление к уровню доказательности, сопоставимому с рандомизированным экспериментом</p></td></tr><tr><td><p>Компонентная</p></td><td><p>Стандартизированные наборы данных</p><p>Конфигурационные файлы</p><p>Визуализации и отчеты</p></td><td><p>Стандартизированные наборы данных</p><p>Конфигурационные файлы</p><p>Визуализации и отчеты</p></td><td><p>Компонент ETL-пайплайна предоставляет очищенные и агрегированные данные Компоненту анализа. Компонент анализа (реализующий методы Causal Inference) использует данные и конфигурацию, выполняет вычисления и передает результаты Компоненту визуализации. Компонент визуализации генерирует интерактивные дашборды и отчеты для конечного потребителя. Компонент оркестрации (Apache Airflow) управляет всем workflow: запускает ETL, затем анализ, затем визуализацию</p></td><td><p>Внутри среды выполнения анализа компоненты развернуты в едином вычислительном кластере</p><p>Компонент ETL подключен к Хранилищу Данных (DWH), компонент визуализации публикует отчеты в корпоративной системе</p></td><td><p>Data Engineer</p><p>Продуктовый аналитик</p></td><td><p>Запуск по расписанию</p><p>Последовательность выполнения: Строгий порядок: ETL, Анализ, Визуализация. Компоненты выполняются последовательно как этапы workflow</p></td></tr></tbody></table></div>
